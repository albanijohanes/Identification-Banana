# %%
from PIL import Image
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def compress_images_in_directory(directory, output_directory, quality):
    # Membuat direktori output jika belum ada
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Mengompresi setiap file gambar dalam direktori
    for filename in os.listdir(directory):
        if filename.endswith(".jpg"):
            input_path = os.path.join(directory, filename)
            output_path = os.path.join(output_directory, filename)
            compress_image(input_path, output_path, quality)

def compress_image(input_path, output_path, quality):
    image = Image.open(input_path)
    image.save(output_path, optimize=True, quality=quality)

input_directory = '/content/drive/MyDrive/Project Siscer/Dataset/train-1'
output_directory = '/content/drive/MyDrive/Project Siscer/Dataset/train'
quality = 1

compress_images_in_directory(input_directory, output_directory, quality)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e8b8c20eac22> in <cell line: 21>()
#      19 quality = 1
#      20
# ---> 21 compress_images_in_directory(input_directory, output_directory, quality)
#
# <ipython-input-7-e8b8c20eac22> in compress_images_in_directory(directory, output_directory, quality)
#       9             input_path = os.path.join(directory, filename)
#      10             output_path = os.path.join(output_directory, filename)
# ---> 11             compress_image(input_path, output_path, quality)
#      12
#      13 def compress_image(input_path, output_path, quality):
#
# <ipython-input-7-e8b8c20eac22> in compress_image(input_path, output_path, quality)
#      13 def compress_image(input_path, output_path, quality):
#      14     image = Image.open(input_path)
# ---> 15     image.save(output_path, optimize=True, quality=quality)
#      16
# ...

# %%
def compress_images_in_directory(directory, output_directory, quality):
    # Membuat direktori output jika belum ada
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Mengompresi setiap file gambar dalam direktori
    for filename in os.listdir(directory):
        if filename.endswith(".jpg"):
            input_path = os.path.join(directory, filename)
            output_path = os.path.join(output_directory, filename)
            compress_image(input_path, output_path, quality)

def compress_image(input_path, output_path, quality):
    image = Image.open(input_path)
    image.save(output_path, optimize=True, quality=quality)

input_directory = '/content/drive/MyDrive/Project Siscer/Dataset/test-1'
output_directory = '/content/drive/MyDrive/Project Siscer/Dataset/test'
quality = 1

compress_images_in_directory(input_directory, output_directory, quality)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e2024143b181> in <cell line: 21>()
#      19 quality = 1
#      20
# ---> 21 compress_images_in_directory(input_directory, output_directory, quality)
#
# <ipython-input-8-e2024143b181> in compress_images_in_directory(directory, output_directory, quality)
#       9             input_path = os.path.join(directory, filename)
#      10             output_path = os.path.join(output_directory, filename)
# ---> 11             compress_image(input_path, output_path, quality)
#      12
#      13 def compress_image(input_path, output_path, quality):
#
# <ipython-input-8-e2024143b181> in compress_image(input_path, output_path, quality)
#      13 def compress_image(input_path, output_path, quality):
#      14     image = Image.open(input_path)
# ---> 15     image.save(output_path, optimize=True, quality=quality)
#      16
# ...

# %%
def resize_images_in_folder(input_folder, output_folder, new_width, new_height):
  if not os.path.exists(output_directory):
        os.makedirs(output_directory)

  for filename in os.listdir(input_folder):
       if filename.endswith(".jpg"):  # Adjust the file extensions as needed
           input_path = os.path.join(input_folder, filename)
           output_path = os.path.join(output_folder, filename)
           resize_image(input_path, output_path, new_width, new_height)

def resize_image(input_image_path, output_image_path, new_width, new_height):
    image = Image.open(input_image_path)
    resized_image = image.resize((new_width, new_height))
    resized_image.save(output_image_path)


input_folder = '/content/drive/MyDrive/Project Siscer/Dataset/train-1'   # Replace with the path to your input folder
output_folder = '/content/drive/MyDrive/Project Siscer/Dataset/train'  # Replace with the path to your output folder

new_width = 400
new_height = 400

resize_images_in_folder(input_folder, output_folder, new_width, new_height)

# %%
import os
from PIL import Image

def resize_images_in_folder(input_folder, output_folder, new_width, new_height):
    for filename in os.listdir(input_folder):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Adjust the file extensions as needed
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)
            resize_image(input_path, output_path, new_width, new_height)

def resize_image(input_image_path, output_image_path, new_width, new_height):
    image = Image.open(input_image_path)
    resized_image = image.resize((new_width, new_height))
    resized_image.save(output_image_path)


input_folder = '/content/drive/MyDrive/Project Siscer/Dataset/test-1'   # Replace with the path to your input folder
output_folder = '/content/drive/MyDrive/Project Siscer/Dataset/test'  # Replace with the path to your output folder

new_width = 400
new_height = 400

resize_images_in_folder(input_folder, output_folder, new_width, new_height)
